# %% [markdown]
# # Processo de Extração dos dados

# %%
import pandas as pd

# %%
# carregador o dado para um data frame e referenciar o caracter delimitador(separador = sep) dos dados
dataframe = pd.read_csv('ocorrencia_filtrados.csv', sep=';')
dataframe
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1                  BELÉM            PA                 SBBE     03/01/2010
# 2         RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3     LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4                PELOTAS            RS                 SBPK     05/01/2010
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     15/08/2021
# 6110         PORTO VELHO            RO                 SBPV     16/08/2021
# 6111               BELÉM            PA                 SBBE     17/08/2021
# 6112          DOM AQUINO            MT                 ****     18/08/2021
# 6113            CAMPINAS            SP                 SBKP     18/08/2021
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 6109        15:05:00                    0
# 6110        02:30:00                    0
# 6111        15:45:00                    0
# 6112        16:00:00                    0
# 6113        12:45:00                    0
#
# [6114 rows x 9 columns]

# %%
# Visualizar os tipos de dados que estão sendo carregados
dataframe.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %%
# Algumas colunas foram carregadas como objetivo. Exemplo da coluna ocorrencia_dia que é tipo data. 
dataframe.ocorrencia_dia
# Out:
# 0       03/01/2010
# 1       03/01/2010
# 2       03/01/2010
# 3       04/01/2010
# 4       05/01/2010
#            ...
# 6109    15/08/2021
# 6110    16/08/2021
# 6111    17/08/2021
# 6112    18/08/2021
# 6113    18/08/2021
# Name: ocorrencia_dia, Length: 6114, dtype: object

# %%
# ERROR
# Dados de tipo data carregadas como objetos não podemos acessar métodos específicos para se trabalhar com as datas. 
# Por isso é preciso converter.
dataframe.ocorrencia_dia.dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       4
# 4       5
#        ..
# 6109    8
# 6110    8
# 6111    8
# 6112    8
# 6113    8
# Name: ocorrencia_dia, Length: 6114, dtype: int64

# %%
# No método parse_dates é passado as colunas que serão utilizados como tipo date.
# Ele só reconhecerá se todos os dados forma do tipo date.
dataframe = pd.read_csv('ocorrencia_filtrados.csv', sep=';', parse_dates=['ocorrencia_dia'])
dataframe
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1                  BELÉM            PA                 SBBE     2010-03-01
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4                PELOTAS            RS                 SBPK     2010-05-01
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                 ****     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 6109        15:05:00                    0
# 6110        02:30:00                    0
# 6111        15:45:00                    0
# 6112        16:00:00                    0
# 6113        12:45:00                    0
#
# [6114 rows x 9 columns]

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
dataframe.ocorrencia_dia.dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       4
# 4       5
#        ..
# 6109    8
# 6110    8
# 6111    8
# 6112    8
# 6113    8
# Name: ocorrencia_dia, Length: 6114, dtype: int64

# %%
# No método dayfirst é passado que a data é em formato d/m/yyyy e não yyyy/m/d
dataframe = pd.read_csv('ocorrencia_filtrados.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
dataframe.head(10) #Imprimir apenas as primeias 10 linhas
# dataframe.tail(10) #Imprimir apenas as últimas 10 linhas
#Dados NaN são dados de texto não informados, NaT são dados de date não informados. Campo vazio.
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                 ****     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                 ****     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                 ****     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
dataframe.dtypes
# datetime64[ns] não é um formato de tipo de data correto, pois as datas não são validadas.
#Ex: Ter uma data que ultrapassa os limites dos dias ou meses como 03/50/2021
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
import pandera as pa
# Caso a biblioteca pandera não esteja disponível, basta instalar utilizando o pip

# %%
#pip install pandera 
# Depois de instalar a bilioteca é preciso restartar o Kernel
# Out:
# Collecting pandera
#   Downloading pandera-0.8.0-py3-none-any.whl (186 kB)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (20.9)
# Requirement already satisfied: pandas>=1.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (1.2.4)
# Collecting pandas-stubs
#   Downloading pandas_stubs-1.2.0.37-py3-none-any.whl (161 kB)
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: wrapt in c:\users\cicer\appdata\roaming\python\python38\site-packages (from pandera) (1.11.2)
# Collecting pyarrow
#   Downloading pyarrow-6.0.0-cp38-cp38-win_amd64.whl (15.5 MB)
# Requirement already satisfied: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (1.20.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->pandera) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->pandera) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0->pandera) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\cicer\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas>=1.0->pandera) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.6.0->pandera) (3.7.4.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.6.0->pandera) (0.4.3)
# Installing collected packages: typing-inspect, pyarrow, pandas-stubs, pandera
# Successfully installed pandas-stubs-1.2.0.37 pandera-0.8.0 pyarrow-6.0.0 typing-inspect-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandera as pa

# %%
# Montar o schema para validar dados de um dataframe
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String), #ERROR pois há campos vazios
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
# Montar o schema para validar dados de um dataframe
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, nullable=True), #nullable permite dados nulos
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
#Validar Schema
schema.validate(dataframe)
# A vantagem é que se alguma informação estiver errada, ele retornará um erro. Garantindo a integridade dos dados.
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                 ****     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 6109        15:05:00                    0
# 6110        02:30:00                    0
# 6111        15:45:00                    0
# 6112        16:00:00                    0
# 6113        12:45:00                    0
#
# [6114 rows x 9 columns]

# %%
# Montar o schema para validar dados de um dataframe
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), # Expressão para validar as horas H:M:S
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(dataframe)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                 ****     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 3           17:30:00                    0
# 4           19:25:00                    0
# ...              ...                  ...
# 6109        15:05:00                    0
# 6110        02:30:00                    0
# 6111        15:45:00                    0
# 6112        16:00:00                    0
# 6113        12:45:00                    0
#
# [6114 rows x 9 columns]

# %%
# Tratamento de tamanho do dado de estado com tamanho min e max de 2 caracteres
schema = pa.DataFrameSchema(
    columns={
        #'codigo':pa.Column(pa.Int, required=False), #Caso tenha alguma coluna que não é obrigatória ser carregada, pode setar como não requerida
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2)),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), # Expressão para validar as horas H:M:S
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(dataframe)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-35-45256a200765> in <module>
# ----> 1 schema.validate(dataframe)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     483             return check_obj.pandera.add_schema(self)
#     484
# --> 485         return self._validate(
#     486             check_obj=check_obj,
#     487             head=head,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     657                 check_results.append(check_utils.is_table(result))
#     658             except errors.SchemaError as err:
# --> 659                 error_handler.collect_error("schema_component_check", err)
#     660             except errors.SchemaErrors as err:
#     661                 for schema_error_dict in err.schema_errors:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     649         for schema_component in schema_components:
#     650             try:
# --> 651                 result = schema_component(
#     652                     df_to_validate,
#     653                     lazy=lazy,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1984     ) -> Union[pd.DataFrame, pd.Series]:
#    1985         """Alias for ``validate`` method."""
# -> 1986         return self.validate(
#    1987             check_obj, head, tail, sample, random_state, lazy, inplace
#    1988         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     221                     )
#     222             else:
# --> 223                 validate_column(check_obj, column_name)
#     224
#     225         return check_obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     194
#     195         def validate_column(check_obj, column_name):
# --> 196             super(Column, copy(self).set_name(column_name)).validate(
#     197                 check_obj,
#     198                 head,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1942                 )
#    1943             except errors.SchemaError as err:
# -> 1944                 error_handler.collect_error("dataframe_check", err)
#    1945             except Exception as err:  # pylint: disable=broad-except
#    1946                 # catch other exceptions that may occur when executing the
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1937             try:
#    1938                 check_results.append(
# -> 1939                     _handle_check_results(
#    1940                         self, check_index, check, check_obj, *check_args
#    1941                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2331             warnings.warn(error_msg, UserWarning)
#    2332             return True
# -> 2333         raise errors.SchemaError(
#    2334             schema,
#    2335             check_obj,
#
# SchemaError: <Schema Column(name=ocorrencia_uf, type=DataType(str))> failed element-wise validator 0:
# <Check str_length: str_length(2, 2)>
# failure cases:
#    index failure_case
# 0   2227          ***
# 1   5855          ***

# %% [markdown]
# # Processo de Limpeza dos dados
#
# ##### Sempre perguntar para a pessoa que tem domínio do negócio, quais são os dados que podem ser classificados como não informados.
