# %% [markdown]
# # Processo de Transformação dos dados

# %%
import pandas as pd
import pandera as pa

# %%
#Extração
valores_ausentes = ['***','###!','####','****','*****','NULL']

# Função na_values informa os dados que serão identificados como Não Informados NaN
dataframe = pd.read_csv('ocorrencia_filtrados.csv', sep=';', 
                        parse_dates=['ocorrencia_dia'], 
                        dayfirst=True, 
                        na_values=valores_ausentes)
dataframe.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
# Validação
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2)),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), # Expressão para validar as horas H:M:S
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(dataframe)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-19-45256a200765> in <module>
# ----> 1 schema.validate(dataframe)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     483             return check_obj.pandera.add_schema(self)
#     484
# --> 485         return self._validate(
#     486             check_obj=check_obj,
#     487             head=head,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     657                 check_results.append(check_utils.is_table(result))
#     658             except errors.SchemaError as err:
# --> 659                 error_handler.collect_error("schema_component_check", err)
#     660             except errors.SchemaErrors as err:
# ...

# %%
# Validação
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_aerodromo':pa.Column(pa.String),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), # Expressão para validar as horas H:M:S
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(dataframe)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-21-45256a200765> in <module>
# ----> 1 schema.validate(dataframe)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     483             return check_obj.pandera.add_schema(self)
#     484
# --> 485         return self._validate(
#     486             check_obj=check_obj,
#     487             head=head,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     657                 check_results.append(check_utils.is_table(result))
#     658             except errors.SchemaError as err:
# --> 659                 error_handler.collect_error("schema_component_check", err)
#     660             except errors.SchemaErrors as err:
# ...

# %%
# Validação
schema = pa.DataFrameSchema(
    columns={
        'codigo_ocorrencia':pa.Column(pa.Int),
        'codigo_ocorrencia2':pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_aerodromo':pa.Column(pa.String, nullable=True),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), # Expressão para validar as horas H:M:S
        'total_recomendacoes':pa.Column(pa.Int)
    }
)

# %%
schema.validate(dataframe)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
dataframe.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
# Procurando pelo indice
dataframe.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
# Erro pois não é possível percorrer como lista, pegando o último índice
dataframe.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-956a6d3b0917> in <module>
# ----> 1 dataframe.loc[-1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
# ...

# %%
# Com o iloc já é possível
dataframe.iloc[-1]
# Out:
# codigo_ocorrencia                         80259
# codigo_ocorrencia2                        80259
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                      CAMPINAS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBKP
# ocorrencia_dia              2021-08-18 00:00:00
# ocorrencia_hora                        12:45:00
# total_recomendacoes                           0
# Name: 6113, dtype: object

# %%
dataframe.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6109            RECIFE            PE                 SBRF     2021-08-15
# 6110       PORTO VELHO            RO                 SBPV     2021-08-16
# 6111             BELÉM            PA                 SBBE     2021-08-17
# 6112        DOM AQUINO            MT                  NaN     2021-08-18
# 6113          CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 6109        15:05:00                    0
# ...

# %%
dataframe.iloc[10:15] #Busca pelo índice
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# ...

# %%
dataframe.loc[10:15] # Busca pelo label
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# ...

# %%
# Buscar dados de uma coluna
dataframe.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
# outra forma de buscar dados de uma coluna
dataframe['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
# Buscar valores não informados
dataframe.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# Buscar valores nulos
dataframe.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# Quais são as linhas que possuem esses valores não disponíveis/nulos
dataframe.ocorrencia_uf.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6109    False
# 6110    False
# 6111    False
# 6112    False
# 6113    False
# Name: ocorrencia_uf, Length: 6114, dtype: bool

# %%
# Quais são as linhas que possuem esses valores não disponíveis/nulos
dataframe.loc[dataframe.ocorrencia_uf.isnull()]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5855              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5855      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0
# 5855        11:00:00                    0

# %%
# localizando dados, onde os valores uf da ocorrencia não são informados e estão salvos em uma variável
filtro_uf = dataframe.ocorrencia_uf.isnull()
dataframe.loc[filtro_uf]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5855              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5855      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0
# 5855        11:00:00                    0

# %%
filtro_aerodromo = dataframe.ocorrencia_aerodromo.isnull()
dataframe.loc[filtro_aerodromo]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6092              80236               80236                 ACIDENTE
# 6093              80227               80227                 ACIDENTE
# 6096              80229               80229                INCIDENTE
# 6099              80233               80233                 ACIDENTE
# 6112              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro_hora = dataframe.ocorrencia_hora.isnull()
dataframe.loc[filtro_hora]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4102              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4102           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4102             NaN                    0

# %%
# Pelo count, conseguimos identificar a coluna que tem maior dados completos. 
# E as colunas com diferença possuem dados com valores nulos nesse diferença.
dataframe.count()
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6112
# ocorrencia_aerodromo        3658
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
# dtype: int64

# %%
# Ocorrencia com mais de 10 recomendações
filtro_recomendacoes = dataframe.total_recomendacoes > 10
dataframe.loc[filtro_recomendacoes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2797              52265               52265                 ACIDENTE
# 3932              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
# Ocorrencia com mais de 10 recomendações
filtro_recomendacoes = dataframe.total_recomendacoes > 10
dataframe.loc[filtro_recomendacoes,'ocorrencia_cidade']
# Out:
# 63                 SÃO PAULO
# 326           RIO DE JANEIRO
# 530                SÃO PAULO
# 727                 ITÁPOLIS
# 872                   RECIFE
# 884     SÃO JOSÉ DOS PINHAIS
# 1062              UBERLÂNDIA
# 1972                BRASÍLIA
# 2797                  SANTOS
# 3932                 VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
# Ocorrencia com mais de 10 recomendações
filtro_recomendacoes = dataframe.total_recomendacoes > 10
dataframe.loc[filtro_recomendacoes,['ocorrencia_cidade','total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE
filtro_incidente = dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE'
dataframe.loc[filtro_incidente]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6090              80221               80221          INCIDENTE GRAVE
# 6095              80228               80228          INCIDENTE GRAVE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE
filtro_incidente = dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE'
dataframe.loc[filtro_incidente,['ocorrencia_cidade','total_recomendacoes']]
# Out:
#      ocorrencia_cidade  total_recomendacoes
# 7             CANUTAMA                    3
# 8             CASCAVEL                    2
# 9        PARÁ DE MINAS                    0
# 29            CURITIBA                    2
# 35              PALMAS                    0
# ...                ...                  ...
# 6090             MARAÚ                    0
# 6095   ELDORADO DO SUL                    0
# 6097     CAXIAS DO SUL                    0
# 6098   CHAPADÃO DO SUL                    0
# 6104       VOTUPORANGA                    0
#
# [791 rows x 2 columns]

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE E estado == SP
filtro_incidente = dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_uf = dataframe.ocorrencia_uf == 'SP'
dataframe.loc[filtro_incidente & filtro_uf]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5949              80056               80056          INCIDENTE GRAVE
# 6000              80114               80114          INCIDENTE GRAVE
# 6007              80124               80124          INCIDENTE GRAVE
# 6081              80200               80200          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE OU estado == SP
filtro_incidente = dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_uf = dataframe.ocorrencia_uf == 'SP'
dataframe.loc[filtro_incidente | filtro_uf]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE OU classificação == INCIDENTE e estado == SP
# Forma 1
filtro_incidente1 = dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_incidente2 = dataframe.ocorrencia_classificacao == 'INCIDENTE'
filtro_uf = dataframe.ocorrencia_uf == 'SP'
dataframe.loc[(filtro_incidente1 | filtro_incidente2) & filtro_uf]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 6084              80234               80234                INCIDENTE
# 6085              80208               80208                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE OU classificação == INCIDENTE e estado == SP
# Forma 2
filtro_1 = (dataframe.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (dataframe.ocorrencia_classificacao == 'INCIDENTE')
filtro_2 = dataframe.ocorrencia_uf == 'SP'
dataframe.loc[filtro_1 & filtro_2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 6084              80234               80234                INCIDENTE
# 6085              80208               80208                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencia cujo classificação == INCIDENTE GRAVE OU classificação == INCIDENTE e estado == SP
# Forma 3
filtro_1 = dataframe.ocorrencia_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE'])
filtro_2 = dataframe.ocorrencia_uf == 'SP'
dataframe.loc[filtro_1 & filtro_2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 6084              80234               80234                INCIDENTE
# 6085              80208               80208                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Todas as ocorrências cujo a cidade começa com a letras C
filtro_cidade1 = dataframe.ocorrencia_cidade.str[0] =='C'
dataframe.loc[filtro_cidade1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 6094              80225               80225                INCIDENTE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6100              80235               80235                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Todas as ocorrências cujo a cidade termina com a letras A
filtro_cidade2 = dataframe.ocorrencia_cidade.str[-1] =='A'
dataframe.loc[filtro_cidade2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 6093              80227               80227                 ACIDENTE
# 6094              80225               80225                INCIDENTE
# 6102              80240               80240                INCIDENTE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Todas as ocorrências cujo a cidade termina com caracteres NA
filtro_cidade3 = dataframe.ocorrencia_cidade.str[-2:] =='NA'
dataframe.loc[filtro_cidade3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 51                39115               39115                 ACIDENTE
# 81                39914               39914                INCIDENTE
# 86                39993               39993          INCIDENTE GRAVE
# 138               40328               40328                 ACIDENTE
# 147               40321               40321                INCIDENTE
# ...                 ...                 ...                      ...
# 5871              79961               79961                 ACIDENTE
# 5875              79976               79976                 ACIDENTE
# 5899              79991               79991                INCIDENTE
# 6012              80134               80134                INCIDENTE
# 6024              80138               80138                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Todas as ocorrências cujo a cidade contém (em qualquer parte do conteúdo) os caracteres MA
filtro_cidade4 = dataframe.ocorrencia_cidade.str.contains('MA')
dataframe.loc[filtro_cidade4]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6075              80205               80205                INCIDENTE
# 6086              80212               80212                INCIDENTE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227                 ACIDENTE
# 6106              80249               80249                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Todas as ocorrências cujo a cidade contém (em qualquer parte do conteúdo) os caracteres MA ou AL
filtro_cidade5 = dataframe.ocorrencia_cidade.str.contains('MA|AL') #Tem que ser junto
dataframe.loc[filtro_cidade5]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 17                39810               39810                INCIDENTE
# ...                 ...                 ...                      ...
# 6075              80205               80205                INCIDENTE
# 6086              80212               80212                INCIDENTE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227                 ACIDENTE
# 6106              80249               80249                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencias do ano de 2015
# dataframe.dtypes # Ssber o tipo de dado da coluna antes

filtro_ano = dataframe.ocorrencia_dia.dt.year == 2015
dataframe.loc[filtro_ano]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2998              52992               52992          INCIDENTE GRAVE
# 2999              52979               52979                 ACIDENTE
# 3000              53073               53073                INCIDENTE
# 3001              53074               53074                INCIDENTE
# 3002              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3464              60632               60632          INCIDENTE GRAVE
# 3465              60600               60600                INCIDENTE
# 3466              60642               60642                INCIDENTE
# 3467              60631               60631                 ACIDENTE
# 3468              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Ocorrencias do ano de 2015 e mês 12
filtro_ano = dataframe.ocorrencia_dia.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia.dt.month == 12
dataframe.loc[filtro_ano & filtro_mes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53573               53573                INCIDENTE
# 3431              60601               60601                INCIDENTE
# 3432              53634               53634                INCIDENTE
# 3433              53636               53636                INCIDENTE
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
# 3442              53627               53627                INCIDENTE
# ...

# %%
# Ocorrencias do ano de 2015 e mês 12
filtro_ano_mes = (dataframe.ocorrencia_dia.dt.year == 2015) & (dataframe.ocorrencia_dia.dt.month == 12)
dataframe.loc[filtro_ano_mes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53573               53573                INCIDENTE
# 3431              60601               60601                INCIDENTE
# 3432              53634               53634                INCIDENTE
# 3433              53636               53636                INCIDENTE
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
# 3442              53627               53627                INCIDENTE
# ...

# %%
# Ocorrencias do ano de 2015, mês 12 e dia 8
filtro_ano = (dataframe.ocorrencia_dia.dt.year == 2015) & (dataframe.ocorrencia_dia.dt.month == 12) & (dataframe.ocorrencia_dia.dt.day == 8)
dataframe.loc[filtro_ano]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3438             AGUAÍ            SP                  NaN     2015-12-08
# 3439             JALES            SP                 SDJL     2015-12-08
# 3440          CAMPINAS            SP                 SBKP     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3438        14:30:00                    1
# 3439        10:20:00                    0
# 3440        16:19:00                    0
# 3441        13:00:00                    0

# %%
# Ocorrencias do ano de 2015, mês 12 e dia 8
filtro_ano = dataframe.ocorrencia_dia.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia.dt.month == 12
filtro_dia = dataframe.ocorrencia_dia.dt.day == 8
dataframe.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3438             AGUAÍ            SP                  NaN     2015-12-08
# 3439             JALES            SP                 SDJL     2015-12-08
# 3440          CAMPINAS            SP                 SBKP     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3438        14:30:00                    1
# 3439        10:20:00                    0
# 3440        16:19:00                    0
# 3441        13:00:00                    0

# %%
# Ocorrencias do ano de 2015, mês 12 dia entre 3 e 8
filtro_ano = dataframe.ocorrencia_dia.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia.dt.month == 12
filtro_dia = (dataframe.ocorrencia_dia.dt.day >=3) & (dataframe.ocorrencia_dia.dt.day <=8)
dataframe.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
# Ocorrencias do ano de 2015, mês 12 dia entre 3 e 8
filtro_ano = dataframe.ocorrencia_dia.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia.dt.month == 12
filtro_dia_inicio = dataframe.ocorrencia_dia.dt.day >=3
filtro_dia_fim = dataframe.ocorrencia_dia.dt.day <=8
dataframe.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
# Criando nova coluna para unir data e hora
dataframe['ocorrencia_dia_hora'] = dataframe.ocorrencia_dia + ' ' + dataframe.ocorrencia_hora
# Erro - Não é possível unir objetos do tipo data com tipo string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-7e9dca7229f0> in <module>
#       1 # Criando nova coluna para unir data e hora
# ----> 2 dataframe['ocorrencia_dia_hora'] = dataframe.ocorrencia_dia + ' ' + dataframe.ocorrencia_hora
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      87     @unpack_zerodim_and_defer("__add__")
#      88     def __add__(self, other):
# ---> 89         return self._arith_method(other, operator.add)
#      90
#      91     @unpack_zerodim_and_defer("__radd__")
#
# ...

# %%
# Transformando a coluna dia (data) em string para fazer a união com a coluna hora
dataframe.ocorrencia_dia.astype(str) + ' ' + dataframe.ocorrencia_hora
# Out:
# 0       2010-01-03 12:00:00
# 1       2010-01-03 11:05:00
# 2       2010-01-03 03:00:00
# 3       2010-01-04 17:30:00
# 4       2010-01-05 19:25:00
#                ...
# 6109    2021-08-15 15:05:00
# 6110    2021-08-16 02:30:00
# 6111    2021-08-17 15:45:00
# 6112    2021-08-18 16:00:00
# 6113    2021-08-18 12:45:00
# Length: 6114, dtype: object

# %%
# Criando nova coluna para unir data e hora. Transformando a data em string
dataframe['ocorrencia_dia_hora'] = pd.to_datetime(dataframe.ocorrencia_dia.astype(str) + ' ' + dataframe.ocorrencia_hora)

# %%
dataframe.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
# Trabalhando com a coluna de ocorrencia_dia_hora criar normalmente filtrando por ano de 2015, mês 12 dia entre 3 e 8
filtro_ano = dataframe.ocorrencia_dia_hora.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia_hora.dt.month == 12
filtro_dia_inicio = dataframe.ocorrencia_dia_hora.dt.day >=3
filtro_dia_fim = dataframe.ocorrencia_dia_hora.dt.day <=8
dataframe.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
filtro_dia_hora1 = dataframe.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro_dia_hora2 = dataframe.ocorrencia_dia_hora <= '2015-12-08 13:00:00'
dataframe.loc[filtro_dia_hora1 & filtro_dia_hora2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3435    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436          TRINDADE            GO                  NaN     2015-12-06
# 3437         AMERICANA            SP                 SDAI     2015-12-06
# 3439             JALES            SP                 SDJL     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# ...

# %%
# Criando um novo data frame para receber as transformaçõe realizadas das ccorrências do ano de 2015 e mês 03
filtro_ano = dataframe.ocorrencia_dia_hora.dt.year == 2015
filtro_mes = dataframe.ocorrencia_dia_hora.dt.month == 3
dataframe_2015_03 = dataframe.loc[filtro_ano & filtro_mes]

# %%
dataframe_2015_03
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3088              53183               53183                 ACIDENTE
# 3089              53120               53120                 ACIDENTE
# 3090              53109               53109                 ACIDENTE
# 3091              53112               53112                 ACIDENTE
# 3092              53152               53152          INCIDENTE GRAVE
# 3093              53167               53167                INCIDENTE
# 3094              53596               53596                INCIDENTE
# 3095              53149               53149                 ACIDENTE
# 3096              53148               53148                 ACIDENTE
# 3097              53153               53153                INCIDENTE
# 3098              53154               53154                INCIDENTE
# 3099              53238               53238                INCIDENTE
# 3100              53189               53189                INCIDENTE
# ...

# %%
dataframe201503.count()
# Cuidado na hora das agregações com dados não informados.
# Ex: ocorrencia_aerodromo não passará a verdade sobre os dados.
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
# Contar a quantidade de dados por cada linha. Quando não tiver dado, ele contará 0.
dataframe_2015_03.groupby(['codigo_ocorrencia']).count()
# Depende da necessidade, mas é importante escolher uma coluna que tenha dados completos.
# Out:
#                    codigo_ocorrencia2  ocorrencia_classificacao  \
# codigo_ocorrencia
# 53109                               1                         1
# 53112                               1                         1
# 53120                               1                         1
# 53148                               1                         1
# 53149                               1                         1
# 53151                               1                         1
# 53152                               1                         1
# 53153                               1                         1
# 53154                               1                         1
# 53164                               1                         1
# 53165                               1                         1
# 53166                               1                         1
# 53167                               1                         1
# ...

# %%
#Agrupando por colunas
dataframe_2015_03.groupby(['codigo_ocorrencia']).codigo_ocorrencia.count()
# Out:
# codigo_ocorrencia
# 53109    1
# 53112    1
# 53120    1
# 53148    1
# 53149    1
# 53151    1
# 53152    1
# 53153    1
# 53154    1
# 53164    1
# 53165    1
# 53166    1
# 53167    1
# 53168    1
# 53169    1
# 53170    1
# 53178    1
# 53179    1
# 53180    1
# 53181    1
# 53182    1
# 53183    1
# 53184    1
# 53185    1
# 53186    1
# 53187    1
# 53188    1
# 53189    1
# 53190    1
# 53193    1
# 53194    1
# 53211    1
# 53212    1
# 53213    1
# 53238    1
# 53412    1
# 53596    1
# Name: codigo_ocorrencia, dtype: int64

# %%
# Contando por uma coluna que tem os dados completos
dataframe_2015_03.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
# Contando por dados que não tem dado completos
dataframe_2015_03.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
# Em vez de contar por valor de coluna, ele agrupará e contar por registros.
# Assim, a contagem por linhas evitará contar por colunas de valores não identificados
dataframe_2015_03.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
# Ordenar contagem por ordem crescente MENOR -> MAIOR
dataframe_2015_03.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
# Ordenar contagem por ordem decrescente MAIOR -> MENOR
dataframe_2015_03.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
# Agrupando dados por ocorrências, no ano de 2010 nos estados Sudestes
filtro1 = dataframe.ocorrencia_dia.dt.year == 2010
filtro2 = dataframe.ocorrencia_uf.isin(['SP', 'MG', 'ES', 'RJ'])
dataframe_sudeste_2010 = dataframe.loc[filtro1 & filtro2]
dataframe_sudeste_2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# ...

# %%
#Total de ocorrencias classificadas
dataframe_sudeste_2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
#Confirmar a quantidade de ocorrencias
dataframe_sudeste_2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
#Como que as ocorrencias acontecem por estado?
dataframe_sudeste_2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
#Como que as ocorrencias acontecem nos estados por incidente?
dataframe_sudeste_2010.groupby(['ocorrencia_uf','ocorrencia_classificacao',]).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             INCIDENTE                    5
# MG             ACIDENTE                     7
#                INCIDENTE                   39
#                INCIDENTE GRAVE              5
# RJ             ACIDENTE                     9
#                INCIDENTE                   52
#                INCIDENTE GRAVE              4
# SP             ACIDENTE                    24
#                INCIDENTE                   74
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
#Cidades que tiveram mais incidentes
dataframe_sudeste_2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# JUIZ DE FORA              4
# VITÓRIA                   4
# MARÍLIA                   3
# SÃO JOSÉ DOS CAMPOS       3
# SÃO JOSÉ DO RIO PRETO     3
# SOROCABA                  2
# ITANHAÉM                  2
# RIBEIRÃO PRETO            2
# IPATINGA                  2
# POÇOS DE CALDAS           2
# DIVINÓPOLIS               2
# BAURU                     2
# JUNDIAÍ                   2
# ARARAQUARA                2
# CAMPOS DOS GOYTACAZES     2
# AREALVA                   2
# MONTES CLAROS             2
# UBERABA                   2
# POUSO ALEGRE              1
# PIRACICABA                1
# PIRASSUNUNGA              1
# ARRAIAL DO CABO           1
# RESENDE                   1
# PENÁPOLIS                 1
# ...

# %%
filtro_rj = dataframe_sudeste_2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dataframe_sudeste_2010.loc[filtro_rj]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 19               44575               44575                INCIDENTE
# 23               40311               40311                INCIDENTE
# 24               41577               41577                INCIDENTE
# 30               39849               39849                INCIDENTE
# 39               40617               40617                INCIDENTE
# 49               39295               39295                 ACIDENTE
# 71               39987               39987                INCIDENTE
# 101              40210               40210                INCIDENTE
# 105              40209               40209                INCIDENTE
# 107              40330               40330                INCIDENTE
# 119              40190               40190                INCIDENTE
# ...

# %%
# Total de recomendações que teve o RJ 
filtro_rj = dataframe_sudeste_2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dataframe_sudeste_2010.loc[filtro_rj].total_recomendacoes.sum()
# Out:
# 25

# %%
# Confirma o Total de recomendações que teve o RJ 
filtro_rj = dataframe_sudeste_2010.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro_total_recomendacoes = dataframe_sudeste_2010.total_recomendacoes > 0
dataframe_sudeste_2010.loc[filtro_rj & filtro_total_recomendacoes]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 119              40190               40190                INCIDENTE
# 274              41750               41750                 ACIDENTE
# 326              42250               42250                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 119    RIO DE JANEIRO            RJ                 SBGL     2010-04-06
# 274    RIO DE JANEIRO            RJ                 SBJR     2010-07-12
# 326    RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 119        02:35:00                    3 2010-04-06 02:35:00
# 274        19:53:00                    3 2010-07-12 19:53:00
# 326        12:26:00                   19 2010-08-12 12:26:00

# %%
# Total de recomendacoes por cidade
dataframe_sudeste_2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# AMERICANA                 0
# ARARAQUARA                0
# ARAÇATUBA                 0
# AREALVA                   0
# ARRAIAL DO CABO           0
# BAURU                     0
# BEBEDOURO                 0
# BELO HORIZONTE            2
# BOCAINA                   0
# BOITUVA                   1
# BOM JESUS DO AMPARO       0
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# BROTAS                    0
# CAJOBI                    0
# CAMANDUCAIA               9
# CAMPINAS                  0
# CAMPOS DOS GOYTACAZES     0
# CASIMIRO DE ABREU         0
# CONFINS                   0
# COROMANDEL                0
# COSMÓPOLIS                0
# DIAMANTINA                0
# DIVINÓPOLIS               0
# GUARULHOS                 0
# IPATINGA                  0
# IPERÓ                     3
# ITANHAÉM                  1
# ITÁPOLIS                  0
# JUIZ DE FORA              0
# JUNDIAÍ                   7
# LINHARES                  0
# ...

# %%
# Total de aerodromo por cidade
dataframe_sudeste_2010.groupby(['ocorrencia_aerodromo']).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# Name: total_recomendacoes, dtype: int64

# %%
# Total de aerodromo por cidade, agrupandos informações não informadas
dataframe_sudeste_2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# NaN     45
# Name: total_recomendacoes, dtype: int64

# %%
# Total de aerodromo por cidade, sem cidades vazias
filtro_recomendacoes = dataframe_sudeste_2010.total_recomendacoes > 0
dataframe_sudeste_2010.loc[filtro_recomendacoes].groupby(['ocorrencia_aerodromo']).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBBP     9
# SBGL     3
# SBJD     7
# SBJR     3
# SBMT    27
# SBPR     1
# SBRJ    19
# SDOI     1
# Name: total_recomendacoes, dtype: int64

# %%
# Total de ocorrencia por cidade, sem cidades vazias
filtro_recomendacoes_cidade = dataframe_sudeste_2010.total_recomendacoes > 0
dataframe_sudeste_2010.loc[filtro_recomendacoes_cidade].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
# Total de ocorrencia por cidade, sem cidades vazias por ordem crescente
filtro_recomendacoes_cidade = dataframe_sudeste_2010.total_recomendacoes > 0
dataframe_sudeste_2010.loc[filtro_recomendacoes_cidade].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# SÃO PAULO                41
# RIO DE JANEIRO           25
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RESENDE                   8
# JUNDIAÍ                   7
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# Name: total_recomendacoes, dtype: int64

# %%
# Agrupar dentro das cidades o total de recomendacoes por meses
dataframe_sudeste_2010.loc[filtro_recomendacoes_cidade].groupby(['ocorrencia_cidade', dataframe_sudeste_2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# BRAGANÇA PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# IPERÓ                  1                  3
# ITANHAÉM               9                  1
# JUNDIAÍ                5                  5
#                        6                  2
# NOVO HORIZONTE         7                  3
# RESENDE                4                  8
# RIO DE JANEIRO         4                  3
#                        7                  3
#                        8                 19
# SÃO BERNARDO DO CAMPO  1                  2
# SÃO PAULO              1                  8
#                        2                 14
#                        6                  2
#                        11                 6
# ...

# %%
# Confirmar se são paulo atende ao resulto acima
filtro1 = dataframe_sudeste_2010.total_recomendacoes > 0
filtro2 = dataframe_sudeste_2010.ocorrencia_cidade == 'SÃO PAULO'
dataframe_sudeste_2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11               40069               40069                 ACIDENTE
# 58               39275               39275                 ACIDENTE
# 63               39992               39992                 ACIDENTE
# 219              41411               41411          INCIDENTE GRAVE
# 469              43450               43450                 ACIDENTE
# 530              43471               43471                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 11          SÃO PAULO            SP                 SBMT     2010-01-10
# 58          SÃO PAULO            SP                  NaN     2010-02-10
# 63          SÃO PAULO            SP                 SBMT     2010-02-17
# 219         SÃO PAULO            SP                 SBMT     2010-06-08
# 469         SÃO PAULO            SP                 SBMT     2010-11-04
# ...
